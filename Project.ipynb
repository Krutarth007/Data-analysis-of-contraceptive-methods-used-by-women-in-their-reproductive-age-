# %%
import numpy as np
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile

df = pd.read_excel('C:/Users/kp/Desktop/MITA_SEM_1/IDS/UN_Dataset.xlsx', na_values=['..'])

# %%
df
# Out:
#           Country or area  ISO code  Survey \nstart year  Survey \nend year  \
# 0             Afghanistan         4                 1972               1974
# 1             Afghanistan         4                 2000               2000
# 2             Afghanistan         4                 2003               2003
# 3             Afghanistan         4                 2005               2005
# 4             Afghanistan         4                 2006               2006
# 5             Afghanistan         4                 2007               2008
# 6             Afghanistan         4                 2010               2010
# 7             Afghanistan         4                 2010               2011
# 8             Afghanistan         4                 2015               2016
# 9                 Albania         8                 2000               2000
# 10                Albania         8                 2002               2002
# ...

# %%
df.describe()
# Out:
#           ISO code  Survey \nstart year  Survey \nend year   Any method  \
# count  1150.000000          1150.000000        1150.000000  1149.000000
# mean    448.319130          1997.009565        1997.260000    47.335335
# std     244.778463            12.706601          12.741019    23.110651
# min       4.000000          1950.000000        1950.000000     0.800000
# 25%     250.000000          1989.000000        1989.000000    27.000000
# 50%     422.000000          2000.000000        2000.000000    50.700000
# 75%     646.000000          2006.750000        2007.000000    66.600000
# max     894.000000          2016.000000        2016.000000    95.000000
#
#        Any modern method  Female\nsterilization  Male\nsterilization  \
# count        1123.000000             955.000000           675.000000
# mean           38.626803               7.513613             2.021037
# std            22.199552               9.307383             4.236951
# ...

# %%
df.columns
# Out:
# Index(['Country or area', 'ISO code', 'Survey \nstart year',
#        'Survey \nend year', 'Age group', 'Population', 'Any method',
#        'Any modern method', 'Female\nsterilization', 'Male\nsterilization',
#        'IUD', 'Implant', 'Injectable', 'Pill', 'Male condom', 'Female condom',
#        'Vaginal barrier methods', 'Lactational amenorrhea method (LAM)',
#        'Emergency contraception', 'Other modern methods',
#        'Any traditional method', 'Rhythm', 'Withdrawal',
#        'Other traditional methods', 'Unmet need\ntotal', 'Unmet need\nspacing',
#        'Unmet need\nlimiting',
#        'Demand satisfied by modern methods\n(per cent)\n', 'Source',
#        'DataCatalog ID', 'DataCatalog LongName', 'Note on country',
#        'Contraceptive use:\npopulation', 'Contraceptive use:\nmethods',
#        'Contraceptive use:\nresiduals \n(modern methods)',
#        'Contraceptive use:\nresiduals \n(traditional methods)',
# ...

# %%
df.columns = df.columns.str.upper()

# %%
df.columns
# Out:
# Index(['COUNTRY OR AREA', 'ISO CODE', 'SURVEY \nSTART YEAR',
#        'SURVEY \nEND YEAR', 'AGE GROUP', 'POPULATION', 'ANY METHOD',
#        'ANY MODERN METHOD', 'FEMALE\nSTERILIZATION', 'MALE\nSTERILIZATION',
#        'IUD', 'IMPLANT', 'INJECTABLE', 'PILL', 'MALE CONDOM', 'FEMALE CONDOM',
#        'VAGINAL BARRIER METHODS', 'LACTATIONAL AMENORRHEA METHOD (LAM)',
#        'EMERGENCY CONTRACEPTION', 'OTHER MODERN METHODS',
#        'ANY TRADITIONAL METHOD', 'RHYTHM', 'WITHDRAWAL',
#        'OTHER TRADITIONAL METHODS', 'UNMET NEED\nTOTAL', 'UNMET NEED\nSPACING',
#        'UNMET NEED\nLIMITING',
#        'DEMAND SATISFIED BY MODERN METHODS\n(PER CENT)\n', 'SOURCE',
#        'DATACATALOG ID', 'DATACATALOG LONGNAME', 'NOTE ON COUNTRY',
#        'CONTRACEPTIVE USE:\nPOPULATION', 'CONTRACEPTIVE USE:\nMETHODS',
#        'CONTRACEPTIVE USE:\nRESIDUALS \n(MODERN METHODS)',
#        'CONTRACEPTIVE USE:\nRESIDUALS \n(TRADITIONAL METHODS)',
# ...

# %%
df.values
# Out:
# array([['Afghanistan', 4, 1972, ..., nan, nan, nan],
#        ['Afghanistan', 4, 2000, ..., nan, nan, nan],
#        ['Afghanistan', 4, 2003, ..., nan, nan, nan],
#        ...,
#        ['Zimbabwe', 716, 2010, ..., nan, nan, nan],
#        ['Zimbabwe', 716, 2014, ..., nan, nan, nan],
#        ['Zimbabwe', 716, 2015, ..., nan, nan, nan]], dtype=object)

# %%
df.isnull()
# Out:
#       COUNTRY OR AREA  ISO CODE  SURVEY \nSTART YEAR  SURVEY \nEND YEAR  \
# 0               False     False                False              False
# 1               False     False                False              False
# 2               False     False                False              False
# 3               False     False                False              False
# 4               False     False                False              False
# 5               False     False                False              False
# 6               False     False                False              False
# 7               False     False                False              False
# 8               False     False                False              False
# 9               False     False                False              False
# 10              False     False                False              False
# 11              False     False                False              False
# ...

# %%
#Total number of missing values column vise
df.isnull().any()
# Out:
# COUNTRY OR AREA                                          False
# ISO CODE                                                 False
# SURVEY \nSTART YEAR                                      False
# SURVEY \nEND YEAR                                        False
# AGE GROUP                                                False
# POPULATION                                               False
# ANY METHOD                                                True
# ANY MODERN METHOD                                         True
# FEMALE\nSTERILIZATION                                     True
# MALE\nSTERILIZATION                                       True
# IUD                                                       True
# IMPLANT                                                   True
# INJECTABLE                                                True
# PILL                                                      True
# MALE CONDOM                                               True
# ...

# %%
# Columns with NAN using Integer
df.isnull().sum()
# Out:
# COUNTRY OR AREA                                             0
# ISO CODE                                                    0
# SURVEY \nSTART YEAR                                         0
# SURVEY \nEND YEAR                                           0
# AGE GROUP                                                   0
# POPULATION                                                  0
# ANY METHOD                                                  1
# ANY MODERN METHOD                                          27
# FEMALE\nSTERILIZATION                                     195
# MALE\nSTERILIZATION                                       475
# IUD                                                        84
# IMPLANT                                                   726
# INJECTABLE                                                306
# PILL                                                       57
# MALE CONDOM                                                72
# ...

# %%
df.columns = ['COUNTRY','ISO_CODE', "SURVEY_START_YEAR", "SURVEY_END_YEAR", "AGE_GROUP", "POPULATION", "ANY_METHOD", "ANY_MODERN_METHOD", "FEMALE_STERILIZATION", "MALE_STERILIZATION","IUD","IMPLANT","INJECTABLE","PILL","MALE_CONDOM","FEMALE_CONDOM","VAGINAL_BARRIER_METHODS","LACTATIONAL_AMENORRHEA_METHOD", "EMERGENCY_CONTRACEPTION","OTHER_MODERN_METHODS","ANY_TRADITIONAL_METHOD","RHYTHM", "WITHDRAWAL","OTHER_TRADITIONAL_METHODS","UNMET_NEED_TOTAL", "UNMET_NEED_SPACING","UNMET_NEED_LIMITING", "DEMAND_SATISFIED_BY_MODERN_METHODS","SOURCE","DATACATALOG_ID","DATACATALOG_LONGNAME","NOTE_ON_COUNTRY","CONTRACEPTIVE_USE_POPULATION","CONTRACEPTIVE_USE_METHODS","CONTRACEPTIVE_USE_RESIDUALS_MODERN_METHODS", "CONTRACEPTIVE_USE_RESIDUALS_TRADITIONAL_METHODS","UNMET_NEED_POPULATION_INCLUDED", "UNMET_NEED_POPULATION_EXCLUDED","UNMET_NEED_INDICATOR"]

# %%
df_filtered = df

# %%
df_filtered= df_filtered.drop(columns="UNMET_NEED_TOTAL")
df_filtered= df_filtered.drop(columns="UNMET_NEED_SPACING")
df_filtered= df_filtered.drop(columns="UNMET_NEED_LIMITING")
df_filtered= df_filtered.drop(columns="DEMAND_SATISFIED_BY_MODERN_METHODS")
df_filtered= df_filtered.drop(columns="SOURCE")
df_filtered= df_filtered.drop(columns="DATACATALOG_ID")
df_filtered= df_filtered.drop(columns="DATACATALOG_LONGNAME")
df_filtered= df_filtered.drop(columns="NOTE_ON_COUNTRY")
df_filtered= df_filtered.drop(columns="CONTRACEPTIVE_USE_POPULATION")
df_filtered= df_filtered.drop(columns="CONTRACEPTIVE_USE_METHODS")
df_filtered= df_filtered.drop(columns="CONTRACEPTIVE_USE_RESIDUALS_MODERN_METHODS")
df_filtered= df_filtered.drop(columns="CONTRACEPTIVE_USE_RESIDUALS_TRADITIONAL_METHODS")
df_filtered= df_filtered.drop(columns="UNMET_NEED_POPULATION_INCLUDED")
df_filtered= df_filtered.drop(columns="UNMET_NEED_POPULATION_EXCLUDED")
df_filtered= df_filtered.drop(columns="UNMET_NEED_INDICATOR")

# %%
df_filtered2  = df[(df["COUNTRY"] == "Afghanistan")]

# %%
new = df_filtered2[['SURVEY_START_YEAR','FEMALE_STERILIZATION']]

# %%
new
# Out:
#    SURVEY_START_YEAR  FEMALE_STERILIZATION
# 0               1972                   NaN
# 1               2000                   0.8
# 2               2003                   NaN
# 3               2005                   NaN
# 4               2006                   0.7
# 5               2007                   NaN
# 6               2010                   1.4
# 7               2010                   0.6
# 8               2015                   1.8

# %%
new['FEMALE_STERILIZATION'] = new['FEMALE_STERILIZATION'].mask(new['FEMALE_STERILIZATION'].isna() ,1100)
# Out:
# C:\Users\kp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new['FEMALE_STERILIZATION']= new['FEMALE_STERILIZATION'].replace(np.nan, 100)
# Out:
# C:\Users\kp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new
# Out:
#    SURVEY_START_YEAR FEMALE_STERILIZATION
# 0               1972                 1000
# 1               2000                  0.8
# 2               2003                 1000
# 3               2005                 1000
# 4               2006                  0.7
# 5               2007                 1000
# 6               2010                  1.4
# 7               2010                  0.6
# 8               2015                  1.8

# %%
new['SURVEY_START_YEAR'].loc[new['FEMALE_STERILIZATION'] != 1000]
# Out:
# 0    1972
# 1    2000
# 2    2003
# 3    2005
# 4    2006
# 5    2007
# 6    2010
# 7    2010
# 8    2015
# Name: SURVEY_START_YEAR, dtype: int64

# %%
traning= new.loc[new['FEMALE_STERILIZATION'] != 1000]

# %%
traning
# Out:
#    SURVEY_START_YEAR FEMALE_STERILIZATION
# 0               1972                 1000
# 1               2000                  0.8
# 2               2003                 1000
# 3               2005                 1000
# 4               2006                  0.7
# 5               2007                 1000
# 6               2010                  1.4
# 7               2010                  0.6
# 8               2015                  1.8

# %%
testing = new['SURVEY_START_YEAR'].loc[new['FEMALE_STERILIZATION'] == 1000]

# %%
X_train = traning['SURVEY_START_YEAR']

# %%
X_train
# Out:
# 0    1972
# 1    2000
# 2    2003
# 3    2005
# 4    2006
# 5    2007
# 6    2010
# 7    2010
# 8    2015
# Name: SURVEY_START_YEAR, dtype: int64

# %%
y_train = traning['FEMALE_STERILIZATION']
type(y_train)
y_train=y_train.values.reshape(-1,5)
# Out:
# pandas.core.series.Series

# %%
y_train
# Out:
# 0    1000
# 1     0.8
# 2    1000
# 3    1000
# 4     0.7
# 5    1000
# 6     1.4
# 7     0.6
# 8     1.8
# Name: FEMALE_STERILIZATION, dtype: object

# %%
new['FEMALE_STERILIZATION'].loc[new['FEMALE_STERILIZATION'] == 1000]
# Out:
# Series([], Name: FEMALE_STERILIZATION, dtype: object)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
classier = SVC(kernel = 'linear', random_state = 0)

classier.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-130-d70ab4e045a8> in <module>()
#       4 classier = SVC(kernel = 'linear', random_state = 0)
#       5
# ----> 6 classier.fit(X_train,y_train)
#
# C:\Users\kp\Anaconda3\lib\site-packages\sklearn\svm\base.py in fit(self, X, y, sample_weight)
#     147         self._sparse = sparse and not callable(self.kernel)
#     148
# --> 149         X, y = check_X_y(X, y, dtype=np.float64, order='C', accept_sparse='csr')
#     150         y = self._validate_targets(y)
#     151
#
# C:\Users\kp\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...

# %%
classifier.fi

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5)

# %%
classifier.fit(X_train,y_train)
# Out:
# C:\Users\kp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-c8b679b88806> in <module>()
# ----> 1 classifier.fit(X_train,y_train)
#
# C:\Users\kp\Anaconda3\lib\site-packages\sklearn\neighbors\base.py in fit(self, X, y)
#     777             self.outputs_2d_ = True
#     778
# --> 779         check_classification_targets(y)
#     780         self.classes_ = []
#     781         self._y = np.empty(y.shape, dtype=np.int)
#
# C:\Users\kp\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
# ...

# %%
import numpy as np
df_filtered2.loc[df_filtered2['FEMALE_STERILIZATION'].isna()]

# %%
new['FEMALE_STERILIZATION'] = new['FEMALE_STERILIZATION'].mask(new['FEMALE_STERILIZATION'].isna() ,'Unknown')

# %%
new['ST']

# %%
df_filtered2['FEMALE_STERILIZATION']
df_filtered2[df_filtered2['FEMALE_STERILIZATION'].match('Unknown')]

# %%
import math
df_filtered2
gapminder_2002 = df_filtered2[df_filtered2.FEMALE_STERILIZATION == np.nan]
df_filtered2['Discounted_Price'] = df_filtered2.apply(lambda FEMALE_STERILIZATION: FEMALE_STERILIZATION., axis = 1)

# %%
import numpy as np
np.around(df.interpolate(method = 'time'))

# %%
df.duplicated()

# %%
df_drop_dup = df.drop_duplicates()

# %%
df_drop_dup.shape

# %%
# Total Number of Missing NA
df.isnull().sum().sum()

# %%
df_filtered = df

# %% [markdown]
# # Filling the missing values

# %% [markdown]
# Average method was used for

# %%
for index in df_filtered["COUNTRY"]:
    df_filtered["ANY_METHOD"] = df_filtered.ANY_METHOD.fillna(df_filtered['ANY_METHOD'].mean())
    df_filtered["ANY_MODERN_METHOD"] = df_filtered.ANY_METHOD.fillna(df_filtered['ANY_MODERN_METHOD'].mean())
    df_filtered["FEMALE_STERILIZATION"] = df_filtered.FEMALE_STERILIZATION.fillna(df_filtered['FEMALE_STERILIZATION'].mean())
    df_filtered["MALE_STERILIZATION"] = df_filtered.MALE_STERILIZATION.fillna(df_filtered['MALE_STERILIZATION'].mean())
    df_filtered["IUD"] = df_filtered.IUD.fillna(df_filtered['IUD'].mean())
    df_filtered["IMPLANT"] = df_filtered.IMPLANT.fillna(df_filtered['IMPLANT'].mean())
    df_filtered["INJECTABLE"] = df_filtered.INJECTABLE.fillna(df_filtered['INJECTABLE'].mean())
    df_filtered["PILL"] = df_filtered.PILL.fillna(df_filtered['PILL'].mean())
    df_filtered["MALE_CONDOM"] = df_filtered.MALE_CONDOM.fillna(df_filtered['MALE_CONDOM'].mean())
    df_filtered["FEMALE_CONDOM"] = df_filtered.FEMALE_CONDOM.fillna(df_filtered['FEMALE_CONDOM'].mean())
    df_filtered["VAGINAL_BARRIER_METHODS"] = df_filtered.VAGINAL_BARRIER_METHODS.fillna(df_filtered['VAGINAL_BARRIER_METHODS'].mean())
    df_filtered["LACTATIONAL_AMENORRHEA_METHOD"] = df_filtered.LACTATIONAL_AMENORRHEA_METHOD.fillna(df_filtered['LACTATIONAL_AMENORRHEA_METHOD'].mean())
    df_filtered["EMERGENCY_CONTRACEPTION"] = df_filtered.EMERGENCY_CONTRACEPTION.fillna(df_filtered['EMERGENCY_CONTRACEPTION'].mean())
    df_filtered["OTHER_MODERN_METHODS"] = df_filtered.OTHER_MODERN_METHODS.fillna(df_filtered['OTHER_MODERN_METHODS'].mean())
    df_filtered["ANY_TRADITIONAL_METHOD"] = df_filtered.ANY_TRADITIONAL_METHOD.fillna(df_filtered['ANY_TRADITIONAL_METHOD'].mean())
    df_filtered["RHYTHM"] = df_filtered.RHYTHM.fillna(df_filtered['RHYTHM'].mean())
    df_filtered["WITHDRAWAL"] = df_filtered.WITHDRAWAL.fillna(df_filtered['WITHDRAWAL'].mean())
    df_filtered["OTHER_TRADITIONAL_METHODS"] = df_filtered.OTHER_TRADITIONAL_METHODS.fillna(df_filtered['OTHER_TRADITIONAL_METHODS'].mean())

# %%
df_filtered.columns

# %%
df_filtered.info()

# %%
df_filtered.dtypes

# %%
# Import label encoder 
from sklearn import preprocessing 
  
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'species'. 
df_filtered['POPULATION']= label_encoder.fit_transform(df_filtered['POPULATION']) 
  
df_filtered['POPULATION'].unique()

# %%
df_filtered

# %%
import numpy as np
import pandas as pd
outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
    return outliers

# %%
boxplot = df_filtered.boxplot(column=['FEMALE_STERILIZATION'])
boxplot

# %%
df_filtered

# %%
import matplotlib.pyplot as plt

# %%
# create a figure and axis
fig, ax = plt.subplots()

# scatter the sepal_length against the sepal_width
ax.scatter(df_filtered['SURVEY_START_YEAR'], df_filtered["FEMALE_STERILIZATION"])
# set a title and labels
ax.set_title('Iris Dataset')
ax.set_xlabel('Survey Year')
ax.set_ylabel('Overall Utilization of Female Sterilization')

# %%
# create a figure and axis
fig, ax = plt.subplots()

# scatter the sepal_length against the sepal_width
ax.scatter(df_filtered['SURVEY_START_YEAR'], df_filtered["MALE_STERILIZATION"])
# set a title and labels
ax.set_title('Iris Dataset')
ax.set_xlabel('Survey Year')
ax.set_ylabel('Overall Utilization of Male Sterilization')

# %%
df_filtered2  = df_filtered[(df_filtered["COUNTRY"] == "India") | (df_filtered["COUNTRY"] == "")]
fig, ax = plt.subplots()

ax.scatter(df_filtered2['SURVEY_START_YEAR'], df_filtered2["IUD"])
ax.set_title('Iris Dataset')
ax.set_xlabel('Survey Year')
ax.set_ylabel('Overall Utilization of Male Sterilization')

# %% [markdown]
# # Univariate Distribution:

# %%
import seaborn as sns
sns.set(color_codes = True)

# %%
plt.figure(figsize=(9,8))     #this sets the size of figure
sns.distplot(df_filtered['MALE_CONDOM'],bins=50)  #with this we plot histogram of Male Condom and give it's kernel density estimate.
print("Skewness: %f" % df['MALE_CONDOM'].skew())
print("Kurtosis: %f" % df['MALE_CONDOM'].kurt())

# %%
plt.figure(figsize=(9,8))     #this sets the size of figure
sns.distplot(df_filtered['ANY_METHOD'],bins=50)  #with this we plot histogram of Male Condom and give it's kernel density estimate.
print("Skewness: %f" % df['ANY_METHOD'].skew())
print("Kurtosis: %f" % df['ANY_METHOD'].kurt())

# %%
sns.jointplot(x="SURVEY_START_YEAR",y="MALE_CONDOM",data=df_filtered)

# %%
sns.jointplot(x="SURVEY_START_YEAR",y="FEMALE_CONDOM",data=df_filtered)

# %%
import pandas as pd
import pandas_profiling
pandas_profiling.ProfileReport(df_filtered)

# %%
fig = plt.figure(figsize=(10, 25))
sns.set(font_scale=1.5)

# %%
fig1 = fig.add_subplot(221); sns.barplot(x='COUNTRY', y='ANY_METHOD',
data=df_filtered[['ANY_METHOD', 'COUNTRY']])

# %%
fig1 = fig.add_subplot(221); sns.boxplot(x='AGE_GROUP', y='ANY_METHOD',
data=df_filtered2[['ANY_METHOD', 'AGE_GROUP']])

# %%
sns.reset_defaults()
sns.set(style="ticks", color_codes=True)
fig1 = fig.add_subplot(221); sns.barplot(x=df.MALE_CONDOM/df.ANY_METHOD, y='ANY_METHOD',data = df_filtered)

# %%
df_filtered.columns

# %%
df_filtered.hist()

# %%
# plot between 2 attributes 
plt.bar(df_filtered['POPULATION'], df_filtered['ANY_METHOD']) 
plt.xlabel("POPULATION") 
plt.ylabel("ANY_METHOD") 
plt.show()

# %%
df_filtered.plot.box() 

# individual attribute box plot 
plt.boxplot(df_filtered['INJECTABLE']) 
plt.show()

# %%
import numpy as np
np.size(np.unique(df_filtered['COUNTRY']))

# %%
df_filtered['POPULATION'].value_counts().plot(kind="bar", figsize=(15,7), color="#61d199")

# %%
# Recommended way
sns.lmplot(x='SURVEY_START_YEAR', y='ANY_METHOD', data=df_filtered)

# %%
sns.boxplot(data=df_filtered)

# %%
pkmn_type_colors = ['#78C850',  # Grass
                    '#F08030',  # Fire
                    '#6890F0',  # Water
                    '#A8B820',  # Bug
                    '#A8A878',  # Normal
                    '#A040A0',  # Poison
                    '#F8D030',  # Electric
                    '#E0C068',  # Ground
                    '#EE99AC',  # Fairy
                    '#C03028',  # Fighting
                    '#F85888',  # Psychic
                    '#B8A038',  # Rock
                    '#705898',  # Ghost
                    '#98D8D8',  # Ice
                    '#7038F8',  # Dragon
                   ]

# Swarm plot with Pokemon color palette
sns.swarmplot(x='SURVEY_START_YEAR', y='PILL', data=df_filtered, 
              palette=pkmn_type_colors)

# %%
sns.kdeplot(df_filtered2.SURVEY_START_YEAR, df_filtered2.WITHDRAWAL)
